# %%
import numpy as np
from numpy import linalg 
x1,y1=5,5
xp1,yp1=100,100
x2,y2=150,5
xp2,yp2=200,80
x3,y3=150,150
xp3,yp3=220,80
x4,y4=5,150
xp4,yp4=100,200
A=np.array([[-x1,-y1,-1,0,0,0,x1*xp1,y1*xp1,xp1],
          [0,0,0,-x1,-y1,-1,x1*yp1,y1*yp1,yp1],
          [-x2,-y2,-1,0,0,0,x2*xp2,y2*xp2,xp2],
          [0,0,0,-x2,-y2,-1,x2*yp2,y2*yp2,yp2],
          [-x3,-y3,-1,0,0,0,x3*xp3,y3*xp3,xp3],
          [0,0,0,-x3,-y3,-1,x3*yp3,y3*yp3,yp3],
          [-x4,-y4,-1,0,0,0,x4*xp4,y4*xp4,xp4],
          [0,0,0,-x4,-y4,-1,x4*yp4,y4*yp4,yp4]])
# A is 8*9

RA=np.matmul(A.transpose(),A)#right singular vectors 9*9(V)
LA=np.matmul(A,A.transpose())#leftt singular vectors 8*8(U)
w1, v1 = linalg.eig(RA)
#Sorting the eig values and vectors in descending order
w1 = w1[w1.argsort()[::-1]]
v1=v1[w1.argsort()[::-1]]

w2, v2 = linalg.eig(LA)
w2 = w2[w2.argsort()[::-1]]
v2=v2[w2.argsort()[::-1]]
H=np.reshape(v1[:,8],(3,3))#Homography matrix

# %%
H
# Out:
# array([[ 5.31056349e-02, -4.91718842e-03,  6.14648552e-01],
#        [ 1.77018783e-02, -3.93375074e-03,  7.86750146e-01],
#        [ 2.36025044e-04, -4.91718842e-05,  7.62164204e-03]])

# %%
# A=UDV'
#A is 8*9
# U is 8*8 right singular vectors
# D is 8*9 diagonal matrix 
# V is 9*9 left singular vectors
U=v2
#V=v1.transpose()
V=v1
D=np.diag(np.sqrt(w2))
D=np.concatenate((D,np.zeros((8,1))), axis=1)

# %%
D.shape
# Out:
# (8, 9)

# %%
np.matmul(np.matmul(U,D),V)
# Out:
# array([[ 4.15570561e+00,  4.57956358e+00, -2.57641330e+02,
#         -1.37117061e+02, -1.48177206e+02,  1.23188689e+02,
#          6.15681136e+02, -8.96743623e+01,  2.46213497e+01],
#        [ 4.76865960e-01,  1.65608717e+00, -2.55841127e+02,
#         -1.36787291e+02, -1.48108100e+02,  1.24049271e+02,
#          6.15599131e+02, -9.62702926e+01,  1.79275638e+01],
#        [ 1.11436572e+02,  4.03332973e+01, -1.32230822e+04,
#          2.24578589e+02,  1.05349011e+04,  1.61589028e+04,
#          1.85988424e+04, -2.64856889e+03,  1.05924779e+03],
#        [ 4.43784694e+01,  1.61285433e+01, -5.29709718e+03,
#          1.16696931e+02,  4.26935782e+03,  6.38685197e+03,
#          7.46448254e+03, -1.12883120e+03,  3.19038149e+02],
#        [ 1.34645243e+02,  1.46444327e+02, -1.17324395e+04,
#         -7.25379456e+03, -7.65364950e+03,  8.66452587e+03,
#          4.26289470e+04, -5.52331951e+03,  2.52974628e+03],
#        [ 4.92147876e+01,  5.36942742e+01, -4.23938284e+03,
#         -2.62361003e+03, -2.76460708e+03,  3.13947635e+03,
#          1.54974198e+04, -2.20420499e+03,  8.13937552e+02],
#        [ 6.65207366e+00,  4.75344633e+01,  9.98979450e+02,
#         -3.53865769e+03, -8.87102587e+03, -4.06101317e+03,
#          1.06975988e+04, -1.28104169e+03,  7.02529910e+02],
#        [ 1.40696213e+01,  9.49959063e+01,  2.10175208e+03,
#         -7.11468236e+03, -1.78521215e+04, -7.92197853e+03,
#          2.13515501e+04, -2.67858523e+03,  1.22382073e+03]])

# %%
A
# Out:
# array([[   -5,    -5,    -1,     0,     0,     0,   500,   500,   100],
#        [    0,     0,     0,    -5,    -5,    -1,   500,   500,   100],
#        [ -150,    -5,    -1,     0,     0,     0, 30000,  1000,   200],
#        [    0,     0,     0,  -150,    -5,    -1, 12000,   400,    80],
#        [ -150,  -150,    -1,     0,     0,     0, 33000, 33000,   220],
#        [    0,     0,     0,  -150,  -150,    -1, 12000, 12000,    80],
#        [   -5,  -150,    -1,     0,     0,     0,   500, 15000,   100],
#        [    0,     0,     0,    -5,  -150,    -1,  1000, 30000,   200]])

# %%
w2
# Out:
# array([3.62583363e+09, 1.01280011e+09, 6.80651927e+04, 3.46776193e+04,
#        2.12012335e+04, 3.70648899e+03, 1.52001454e+01, 6.56490961e-01])

# %%
w1
# Out:
# array([ 3.62583363e+09,  1.01280011e+09,  6.80651927e+04,  3.46776193e+04,
#         2.12012335e+04,  3.70648899e+03,  1.52001454e+01,  6.56490976e-01,
#        -1.66509311e-10])

# %%
D
# Out:
# array([[6.02148954e+04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [0.00000000e+00, 3.18245207e+04, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 2.60893068e+02, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.86219278e+02,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.45606434e+02, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 6.08809411e+01, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 3.89873639e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 8.10241298e-01,
#         0.00000000e+00]])

# %%
U
# Out:
# array([[ 1.17519867e-02,  3.44207228e-04, -5.15532162e-02,
#         -4.66128587e-01, -2.60345896e-01, -6.78428560e-02,
#         -8.41087769e-01,  1.08122948e-02],
#        [ 1.17517760e-02,  3.43641967e-04, -8.72103737e-02,
#         -4.59351955e-01, -2.49098952e-01, -8.85591890e-02,
#          3.54169470e-01,  7.65455992e-01],
#        [ 3.58735699e-01,  6.54942912e-01,  1.34538659e-02,
#         -4.65084492e-01,  1.70101644e-01,  2.93617516e-01,
#          1.82289869e-01, -2.78385485e-01],
#        [ 1.43494223e-01,  2.61976394e-01, -4.45383120e-01,
#          1.36060221e-01, -5.00795526e-01, -5.87488150e-01,
#          1.52897236e-01, -2.73099287e-01],
#        [ 7.74962678e-01,  2.27117371e-02,  4.08516159e-01,
#          2.84937362e-01,  3.19642679e-02, -2.35211438e-01,
#         -1.59658351e-01,  2.62688693e-01],
#        [ 2.81806634e-01,  8.24745878e-03, -6.92167142e-01,
#          3.15915567e-01,  1.14149714e-02,  5.01908806e-01,
#         -1.69560616e-01,  2.46628160e-01],
#        [ 1.84643411e-01, -3.16806256e-01,  2.48466337e-01,
#         -3.46544961e-02, -6.98268275e-01,  4.67261587e-01,
#          1.81630339e-01, -2.52393737e-01],
#        [ 3.69278450e-01, -6.33614920e-01, -2.88917222e-01,
#         -3.93333286e-01,  3.18917542e-01, -1.75016528e-01,
#          1.52633610e-01, -2.61429001e-01]])

# %%
w2
# Out:
# array([3.62583363e+09, 1.01280011e+09, 6.80651927e+04, 3.46776193e+04,
#        2.12012335e+04, 3.70648899e+03, 1.52001454e+01, 6.56490961e-01])

# %%
w1
# Out:
# array([ 3.62583363e+09,  1.01280011e+09,  6.80651927e+04,  3.46776193e+04,
#         2.12012335e+04,  3.70648899e+03,  1.52001454e+01,  6.56490976e-01,
#        -1.66509311e-10])
